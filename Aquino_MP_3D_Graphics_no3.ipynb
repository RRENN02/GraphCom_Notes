# %% [markdown]
# ## MP 3D GRAPHICS IN PYTHON
#     Name: Nathaniel Ken A. Aquino
#     Section: 4CSC
# ----

# %%
# Imports
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from mpl_toolkits.mplot3d.art3d import Poly3DCollection

# %% [markdown]
# 3. Draw the following in Python and compute for the volume of each 3D image (all edge color must be red).
#
#     [a. Cylinder whose radius = 13.3, height = 17 and number of points/resolution = 450 (yellow)](#1) <br>
#
#     [b. Cone whose radius = 13.3, height = 17 and number of points/resolution = 450 (cyan)](#2) <br>
#
#     [c. Sphere whose radius = 13.3 and number of points/resolution = 450 (magenta)](#3) <br>
#
#     [d. Cube whose initial coordinate located at (4, 8, 9) and the edge is 12. (blue)](#4) <br>
#
#     [e. Pyramid whose base is rectangle (L = 21 and W = 16) and height is 23 units. (green)](#5) <br>
#
#     [f. Prism whose base is rectangle (L = 21 and W = 16) and height is 23 units. (orange)](#6) <br>

# %% [markdown]
# <a id="1"></a> <br>
# ### 1 : Cylinder

# %%
# Define the parameters for the cylinder
radius = 13.3
height = 17
resolution = 450

# Create the mesh for the cylinder
theta = np.linspace(0, 2 * np.pi, resolution)
z = np.linspace(0, height, resolution)
theta, z = np.meshgrid(theta, z)

x = radius * np.cos(theta)
y = radius * np.sin(theta)

# Plot the cylinder
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(x, y, z, color='yellow', edgecolor='red')

# Compute the volume of the cylinder
cylinder_volume = np.pi * radius**2 * height
print(f"Volume of the cylinder: {cylinder_volume}")

# Set labels for clarity
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')

plt.show()
# Out:
# Volume of the cylinder: 9447.177516389474

# %% [markdown]
# <a id="2"></a> <br>
# ### 2 : Cone

# %%
# Define the parameters for the cone
cone_radius = 13.3
cone_height = 17
resolution = 450

# Create a meshgrid for the cone's angle (theta) and height (z)
theta = np.linspace(0, 2*np.pi, resolution)
z = np.linspace(0, height, resolution)
theta, Z = np.meshgrid(theta, z)

# Parametric equations for the cone
X = radius * (1 - Z/height) * np.cos(theta)
Y = radius * (1 - Z/height) * np.sin(theta)

# Plot the cone
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(X, Y, Z, rstride=5, cstride=5, color='RED', edgecolor='BLUE')

# Set labels for clarity
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')

# Compute the volume of the cone
cone_volume = (1/3) * np.pi * cone_radius**2 * cone_height
print(f"Volume of the cone: {cone_volume}")

plt.show()
# Out:
# Volume of the cone: 3149.059172129825

# %% [markdown]
# <a id="3"></a> <br>
# ### 3 : Sphere

# %%
# Define the parameters for the sphere
sphere_radius = 13.3
sphere_resolution = 450

# Create a meshgrid for the sphere's angles (theta and phi)
theta = np.linspace(0, 2 * np.pi, sphere_resolution)
phi = np.linspace(0, np.pi, sphere_resolution)
theta, phi = np.meshgrid(theta, phi)

# Parametric equations for the sphere
x = sphere_radius * np.sin(phi) * np.cos(theta)
y = sphere_radius * np.sin(phi) * np.sin(theta)
z = sphere_radius * np.cos(phi)

# Plot the sphere
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(x, y, z, color='magenta', edgecolor='red')

# Set labels for clarity
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')

# Compute the volume of the sphere
sphere_volume = (4/3) * np.pi * sphere_radius**3
print(f"Volume of the sphere: {sphere_volume}")

plt.show()
# Out:
# Volume of the sphere: 9854.70282101804

# %% [markdown]
# <a id="4"></a> <br>
# ### 4 : Cube

# %%
# Define the initial coordinate and edge length of the cube
initial_coord = (4, 8, 9)
edge_length = 12

# Define the vertices of the cube based on the initial coordinate and edge length
vertices = np.array([
    [initial_coord[0], initial_coord[1], initial_coord[2]],  # Corner 1
    [initial_coord[0] + edge_length, initial_coord[1], initial_coord[2]],  # Corner 2
    [initial_coord[0] + edge_length, initial_coord[1] + edge_length, initial_coord[2]],  # Corner 3
    [initial_coord[0], initial_coord[1] + edge_length, initial_coord[2]],  # Corner 4
    [initial_coord[0], initial_coord[1], initial_coord[2] + edge_length],  # Corner 5
    [initial_coord[0] + edge_length, initial_coord[1], initial_coord[2] + edge_length],  # Corner 6
    [initial_coord[0] + edge_length, initial_coord[1] + edge_length, initial_coord[2] + edge_length],  # Corner 7
    [initial_coord[0], initial_coord[1] + edge_length, initial_coord[2] + edge_length]   # Corner 8
])

# Define the 6 faces of the cube using vertex indices
faces = [
    [vertices[0], vertices[1], vertices[2], vertices[3]],  # Bottom
    [vertices[4], vertices[5], vertices[6], vertices[7]],  # Top
    [vertices[0], vertices[1], vertices[5], vertices[4]],  # Front
    [vertices[2], vertices[3], vertices[7], vertices[6]],  # Back
    [vertices[1], vertices[2], vertices[6], vertices[5]],  # Right
    [vertices[4], vertices[7], vertices[3], vertices[0]]   # Left
]

# Create the 3D plot
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Add the faces to the plot
ax.add_collection3d(Poly3DCollection(faces, facecolors='blue', linewidths=1, edgecolors='red', alpha=.30))

# Set labels for clarity
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')

# Set limits for the axes
ax.set_xlim([initial_coord[0], initial_coord[0] + edge_length])
ax.set_ylim([initial_coord[1], initial_coord[1] + edge_length])
ax.set_zlim([initial_coord[2], initial_coord[2] + edge_length])

# Compute the volume of the cube
cube_volume = edge_length ** 3
print(f"Volume of the cube: {cube_volume}")

# Show the plot
plt.show()
# Out:
# Volume of the cube: 1728

# %% [markdown]
# <a id="5"></a> <br>
# ### 5 : Pyramid

# %%
# Define the parameters for the pyramid
pyramid_base_length = 21
pyramid_base_width = 16
pyramid_height = 23

# Define the vertices of the pyramid
pyramid_vertices = np.array([
    [0, 0, 0],  # Base corner 1
    [pyramid_base_length, 0, 0],  # Base corner 2
    [pyramid_base_length, pyramid_base_width, 0],  # Base corner 3
    [0, pyramid_base_width, 0],  # Base corner 4
    [pyramid_base_length / 2, pyramid_base_width / 2, pyramid_height]  # Apex
])

# Define the faces of the pyramid using vertex indices
pyramid_faces = [
    [pyramid_vertices[0], pyramid_vertices[1], pyramid_vertices[4]],  # Side 1
    [pyramid_vertices[1], pyramid_vertices[2], pyramid_vertices[4]],  # Side 2
    [pyramid_vertices[2], pyramid_vertices[3], pyramid_vertices[4]],  # Side 3
    [pyramid_vertices[3], pyramid_vertices[0], pyramid_vertices[4]],  # Side 4
    [pyramid_vertices[0], pyramid_vertices[1], pyramid_vertices[2], pyramid_vertices[3]]  # Base
]

# Create the 3D plot
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Add the faces to the plot
ax.add_collection3d(Poly3DCollection(pyramid_faces, facecolors='green', linewidths=1, edgecolors='red', alpha=.30))

# Set labels for clarity
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')

# Set limits for the axes
ax.set_xlim([0, pyramid_base_length])
ax.set_ylim([0, pyramid_base_width])
ax.set_zlim([0, pyramid_height])

# Compute the volume of the pyramid
pyramid_volume = (1/3) * pyramid_base_length * pyramid_base_width * pyramid_height
print(f"Volume of the pyramid: {pyramid_volume}")

# Show the plot
plt.show()
# Out:
# Volume of the pyramid: 2576.0

# %% [markdown]
# <a id="6"></a> <br>
# ### 6 : Prism

# %%
# Define the parameters for the rectangular prism
prism_base_length = 21
prism_base_width = 16
prism_height = 23

# Define the vertices of the rectangular prism
prism_vertices = np.array([
    [0, 0, 0],  # Base corner 1
    [prism_base_length, 0, 0],  # Base corner 2
    [prism_base_length, prism_base_width, 0],  # Base corner 3
    [0, prism_base_width, 0],  # Base corner 4
    [0, 0, prism_height],  # Top corner 1
    [prism_base_length, 0, prism_height],  # Top corner 2
    [prism_base_length, prism_base_width, prism_height],  # Top corner 3
    [0, prism_base_width, prism_height]  # Top corner 4
])

# Define the faces of the rectangular prism using vertex indices
prism_faces = [
    [prism_vertices[0], prism_vertices[1], prism_vertices[2], prism_vertices[3]],  # Base
    [prism_vertices[4], prism_vertices[5], prism_vertices[6], prism_vertices[7]],  # Top
    [prism_vertices[0], prism_vertices[1], prism_vertices[5], prism_vertices[4]],  # Side 1
    [prism_vertices[1], prism_vertices[2], prism_vertices[6], prism_vertices[5]],  # Side 2
    [prism_vertices[2], prism_vertices[3], prism_vertices[7], prism_vertices[6]],  # Side 3
    [prism_vertices[3], prism_vertices[0], prism_vertices[4], prism_vertices[7]]   # Side 4
]

# Create the 3D plot
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Add the faces to the plot
ax.add_collection3d(Poly3DCollection(prism_faces, facecolors='orange', linewidths=1, edgecolors='red', alpha=.30))

# Set labels for clarity
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')

# Set limits for the axes
ax.set_xlim([0, prism_base_length])
ax.set_ylim([0, prism_base_width])
ax.set_zlim([0, prism_height])

# Compute the volume of the rectangular prism
prism_volume = prism_base_length * prism_base_width * prism_height
print(f"Volume of the rectangular prism: {prism_volume}")

# Show the plot
plt.show()
# Out:
# Volume of the rectangular prism: 7728

# %% [markdown]
# ----
